# %% [markdown]
# # 중복제거 안된 24시간 데이터 전처리

# %%
import pandas as pd
import os
import datetime
from statsmodels.formula.api import ols
from matplotlib import rc

# %%
pd.options.display.max_colwidth = 1000

# %% [markdown]
# # 전처리

# %% [markdown]
# ## 0928

# %%
path = './전처리/0928/'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.xlsx')]

# %%
df = pd.DataFrame()
for i in file_list_py:
    data = pd.read_excel(path+i)
    df = pd.concat([df,data])
    
df = df.reset_index(drop = True)

# %%
df
# Out:
#             num     region                         title category      time  \
# 0     289502961  도봉구 도봉제2동                   cj제일제당 선물세트  생활/가공식품      5일 전
# 1     287598338   도봉구 창제1동  (미개봉새상품) DUNLOP 남성 스킨로션 선물세트    뷰티/미용     11일 전
# 2     286049252   도봉구 창제5동              롯데 수제명작 수제햄 선물세트  생활/가공식품     14일 전
# 3     287506463     도봉구 창동      스팸8호 선물세트 ( 개봉상품, 쇼핑백있음)  생활/가공식품     11일 전
# 4     286367303  도봉구 방학제1동   [미개봉 새제품] 정관장 선물세트 다보록 여유담편  생활/가공식품  끌올 12일 전
# ...         ...        ...                           ...      ...       ...
# 6005  288648127    양천구 목2동                추석선물 일품진성 홍삼세트  생활/가공식품      7일 전
# 6006  289269423   양천구 신정6동         테소리 도리엔테 2종 선물세트(미개봉)    뷰티/미용   끌올 1일 전
# 6007  288808580   양천구 신정6동             청정원 햄 선물세트 판매합니다.  생활/가공식품   끌올 5일 전
# 6008  289761109   양천구 신월2동                 스팸 선물세트 1만8천원  생활/가공식품      5일 전
# 6009  287934495    양천구 목2동             중국 월병 추석선물세트 11개입  생활/가공식품     10일 전
#
# ...

# %%
df['date'] = '210928'
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6010 entries, 0 to 6009
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   num       6010 non-null   int64
#  1   region    6010 non-null   object
#  2   title     6010 non-null   object
#  3   category  6010 non-null   object
#  4   time      6010 non-null   object
#  5   price     6010 non-null   int64
#  6   detail    5994 non-null   object
#  7   interest  6010 non-null   int64
#  8   chat      6010 non-null   int64
#  9   view      6010 non-null   int64
#  10  date      6010 non-null   object
# dtypes: int64(5), object(6)
# memory usage: 563.4+ KB

# %%
df['date']=pd.to_datetime(df['date'], format="%y%m%d")

# %%
df.head(2)
# Out:
#          num     region                         title category   time  price  \
# 0  289502961  도봉구 도봉제2동                   cj제일제당 선물세트  생활/가공식품   5일 전  15000
# 1  287598338   도봉구 창제1동  (미개봉새상품) DUNLOP 남성 스킨로션 선물세트    뷰티/미용  11일 전  10000
#
#                                               detail  interest  chat  view  \
# 0  3세트 있어요. 한세트당 가격입니다.\n스팸6개 해바라기씨유 2개 들어 있어요\n가...         1     0    92
# 1  박스채 그대로 미개봉 새상품 남성 스킨 로션 선물세트입니다,\n용량은 본품 각 15...         1     1    60
#
#         date
# 0 2021-09-28
# 1 2021-09-28

# %%
df.to_csv('./seoul_210928_date.csv',encoding='utf-8-sig')

# %% [markdown]
# ## 0929

# %%
path = './전처리/0929/'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.xlsx')]

# %%
df29 = pd.DataFrame()
for i in file_list_py:
    data = pd.read_excel(path+i)
    df29 = pd.concat([df29,data])
    
df29 = df29.reset_index(drop = True)

# %%
df29
# Out:
#             num     region                                      title  \
# 0     281728179   구로구 신도림동                                  양키캔들 선물세트
# 1     286132961    구로구 구로동                                  임실치즈 선물세트
# 2     290253446  구로구 오류제1동                           동원.건겅한2호..선물..세트
# 3     291635384  구로구 개봉제3동                                   청정원 선물세트
# 4     287004036    구로구 구로동                        선물세트 동원 스페셜 24호 팝니다
# ...         ...        ...                                        ...
# 4195  286906186    관악구 신림동                       설화수 2종 선물세트. 미개봉 새상품
# 4196  188952648    관악구 봉천동                               벨라수 선물세트+클렌져
# 4197  287859962    관악구 봉천동                                   동원참치선물셋트
# 4198  285173959    관악구 행운동  (새상품) 미샤 고급 한방라인 기초화장품\n초공진 영안 3종세트  선물세트
# 4199  258465109    관악구 청림동              프레쉬 핸드크림+립밤세트 (선물포장 o) / 가격내림
#
#      category       time  price  \
# 0     생활/가공식품  끌올 22시간 전  20000
# 1     생활/가공식품    끌올 4일 전  48000
# ...

# %%
df29['date'] = '210929'
df29['date']=pd.to_datetime(df29['date'], format="%y%m%d")

# %%
df29.head(2)
# Out:
#          num    region      title category       time  price  \
# 0  281728179  구로구 신도림동  양키캔들 선물세트  생활/가공식품  끌올 22시간 전  20000
# 1  286132961   구로구 구로동  임실치즈 선물세트  생활/가공식품    끌올 4일 전  48000
#
#                                          detail  interest  chat  view  \
# 0  양키캔들 블랙체리 향,\n모자이크 자쉐이드 (가로21 세로13 높이11) 입니다         4     0   473
# 1                         구로역 직거래 가능하고 쇼핑백도 있어요         9     2   683
#
#         date
# 0 2021-09-29
# 1 2021-09-29

# %%
df29.to_csv('./seoul_210929_date.csv',encoding='utf-8-sig')

# %% [markdown]
# ## 0930

# %%
path = './전처리/0930/'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.xlsx')]

# %%
df30 = pd.DataFrame()
for i in file_list_py:
    data = pd.read_excel(path+i)
    df30 = pd.concat([df30,data])
    
df30 = df30.reset_index(drop = True)

# %%
df30
# Out:
#             num     region                                              title  \
# 0     285908256   성북구 하월곡동                                 블랙라벨 T호 스팸 명절 선물세트
# 1     288921368    성북구 장위동                                  한우 소고기 선물세트 1.4kg
# 2     285663874    성북구 정릉동                                  버츠비 선물 세트 미사용 새제품
# 3     272099415    성북구 길음동                           프로바이오틱스 석류콜라겐 원액 2병 선물세트
# 4     288967520    성북구 삼선동                                   후레쉬 프리미엄 오일 선물세트
# ...         ...        ...                                                ...
# 4231  286262534    금천구 독산동  (추석선물세트) CJ제일제당 현명한선택E호(구 CJ현명한선택6호) 스팸/해바라기씨유...
# 4232  286314154    금천구 가산동                   [미개봉 초특가] lg생활건강 생활의 품격 24호 선물세트
# 4233  287350769    금천구 독산동                              백설 식용유, 올리고당, 식초 선물세트
# 4234  287182877  금천구 시흥제2동                        LG 생활건강 히말라야 핑크솔트 펌핑치약 선물세트
# 4235  288122954  금천구 시흥제1동                                          엘지생활 선물세트
#
# ...

# %%
df30['date'] = '210930'
df30['date']=pd.to_datetime(df30['date'], format="%y%m%d")

# %%
df30.head(2)
# Out:
#          num    region               title category      time   price  \
# 0  285908256  성북구 하월곡동  블랙라벨 T호 스팸 명절 선물세트  생활/가공식품  끌올 11일 전   39000
# 1  288921368   성북구 장위동   한우 소고기 선물세트 1.4kg  생활/가공식품      8일 전  100000
#
#                                               detail  interest  chat  view  \
# 0  방금 마트에서 56000원 주고 산 선물세트입니다.\n스팸 12개+안달루시안산 올리...         3     2   679
# 1  농협안심한우 소한마리 한우선물세트 \n카카오톡 선물하기로 받은거구요\n현재 배송대기...        10     3   703
#
#         date
# 0 2021-09-30
# 1 2021-09-30

# %%
df30.to_csv('./seoul_210930_date.csv',encoding='utf-8-sig')

# %% [markdown]
# ## 1001

# %%
path = './전처리/1001/'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.xlsx')]

df01 = pd.DataFrame()
for i in file_list_py:
    data = pd.read_excel(path+i)
    df01 = pd.concat([df01,data])
    
df01 = df01.reset_index(drop = True)

# %%
df01
# Out:
#             num    region                   title category       time  price  \
# 0     286988744  강북구 수유3동  동원 선물세트 99-R호 팔아요(새제품)  생활/가공식품    끌올 5일 전  30000
# 1     287973377   강북구 번1동  특 프리미엄 사과 선물세트 추석선물 명절  생활/가공식품      12일 전  35000
# 2     286826259   강북구 번2동       투썸 스페셜 기프트세트 선물세트  생활/가공식품    끌올 4일 전  10000
# 3     292100762   강북구 미아동            명절에받은새상품선물세트  생활/가공식품       3일 전  22000
# 4     286501212   강북구 수유동       수삼 허니셋트 (명절 선물용)   생활/가공식품   끌올 12일 전  40000
# ...         ...       ...                     ...      ...        ...    ...
# 3075  280506381    종로구 계동        시슬리 향수 바디크림 선물세트    뷰티/미용   끌올 11일 전  90000
# 3076  289553475   종로구 숭인동       (새상품*선물세트)키엘 핸드크림    뷰티/미용    끌올 3일 전  17000
# 3077  280994419   종로구 동숭동          아기 새옷) 출산 선물세트      유아동  끌올 21시간 전  25000
# 3078  287539183   종로구 원서동                선물세트 광천김  생활/가공식품    끌올 7일 전  10000
# 3079  282718797   종로구 옥인동            LG생활건강 선물세트   생활/가공식품   끌올 16일 전  15000
#
# ...

# %%
df01['date'] = '211001'
df01['date']=pd.to_datetime(df01['date'], format="%y%m%d")
df01.head(2)
# Out:
#          num    region                   title category     time  price  \
# 0  286988744  강북구 수유3동  동원 선물세트 99-R호 팔아요(새제품)  생활/가공식품  끌올 5일 전  30000
# 1  287973377   강북구 번1동  특 프리미엄 사과 선물세트 추석선물 명절  생활/가공식품    12일 전  35000
#
#                     detail  interest  chat  view       date
# 0  이번 추석선물로 받은거라 유통기한 넉넉해요         4     0   412 2021-10-01
# 1     쿨거래 환영\n과일이 많아 판매합니다         1     1   145 2021-10-01

# %%
df01.to_csv('./seoul_211001_date.csv',encoding='utf-8-sig')

# %% [markdown]
# ## 1002

# %%
path = './전처리/1002/'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.xlsx')]

df02 = pd.DataFrame()
for i in file_list_py:
    data = pd.read_excel(path+i)
    df02 = pd.concat([df02,data])
    
df02 = df02.reset_index(drop = True)
df02
# Out:
#             num     region                              title category  \
# 0     291582404    마포구 성산동                      한과선물세트2단(새상품)  생활/가공식품
# 1     291871893    마포구 동교동  독일제 스테인리스 수통 플라스크 선물세트 위스키, 보드카 등  남성패션/잡화
# 2     289780760    마포구 대흥동        [선물세트] 샹달프 잼 4종 세트(284g*4개)  생활/가공식품
# 3     286327521    마포구 합정동         드리오 녹용홍삼진액 선물세트 새제품 쇼핑백포함   생활/가공식품
# 4     291590476    마포구 상암동                         선물 세트 여러가지  기타 중고물품
# ...         ...        ...                                ...      ...
# 3050  293407293  동작구 사당제2동                 타이틀리스트 골프공&지갑 선물세트   스포츠/레저
# 3051  288450640    동작구 대방동                            동원 선물세트  생활/가공식품
# 3052  293094065  동작구 사당제5동                  쟈뎅 프리미엄 선물셋트 판매해요  생활/가공식품
# 3053  287910222   동작구 노량진동                   cj 현명한선택 f호 선물세트  생활/가공식품
# 3054  278687654    동작구 사당동                     [새상품] 오설록 선물세트  생활/가공식품
#
#            time  price                                             detail  \
# ...

# %%
df02['date'] = '211002'
df02['date']=pd.to_datetime(df02['date'], format="%y%m%d")
df02.head(2)
# Out:
#          num   region                              title category  time  \
# 0  291582404  마포구 성산동                      한과선물세트2단(새상품)  생활/가공식품  5일 전
# 1  291871893  마포구 동교동  독일제 스테인리스 수통 플라스크 선물세트 위스키, 보드카 등  남성패션/잡화  4일 전
#
#    price                                             detail  interest  chat  \
# 0  22000  (유통기한 - 2022년1월10일)\n(쇼핑백 X)\n쇼핑백을 못찾아서 박스만 들고...         0     1
# 1  50000       독일에서 구입한 스테인리스 수통입니다. \n한 손에 딱 잡히는 사이즈 입니다.          2     0
#
#    view       date
# 0    91 2021-10-02
# 1    77 2021-10-02

# %%
df02.to_csv('./seoul_211002_date.csv',encoding='utf-8-sig')

# %% [markdown]
# ## 1003

# %%
path = './전처리/1003/'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.xlsx')]

df03 = pd.DataFrame()
for i in file_list_py:
    data = pd.read_excel(path+i)
    df03 = pd.concat([df03,data])
    
df03 = df03.reset_index(drop = True)
df03
# Out:
#             num     region                      title category     time  \
# 0     286628166    관악구 봉천동               오뚜기 선물세트 팝니당  생활/가공식품  끌올 2일 전
# 1     269067598    관악구 신원동            보온병 선물세트 2종 새상품  생활/가공식품  끌올 1일 전
# 2     293053719    관악구 봉천동   바디판타지 선물세트 미개봉 - 피치 애프리콧    뷰티/미용     3일 전
# 3     256465458    관악구 신원동           알프스 면기세트 선물용 새상품  생활/가공식품  끌올 2일 전
# 4     293389549    관악구 신원동  (새제품) 탬버린즈 핸드크림 손소독제 선물세트    뷰티/미용     2일 전
# ...         ...        ...                        ...      ...      ...
# 3039  216475514  성북구 보문동2가      <새제품>우드윅 향초 미니워머 선물세트  가구/인테리어  끌올 3일 전
# 3040  284796568  성북구 길음제1동      💓성찬식품 누룽지 선물 세트 A 판매💓  생활/가공식품  끌올 5일 전
# 3041  291203063  성북구 삼선동1가                lg생활건강 선물세트    뷰티/미용     7일 전
# 3042  289695732   성북구 상월곡동           선물세트 동원스페셜 3호 급처  생활/가공식품  끌올 1일 전
# 3043  286633991    성북구 종암동    CJ제일제당 스팸 고급유 108호 선물세트  기타 중고물품  끌올 3일 전
#
#       price                                             detail  interest  \
# ...

# %%
df03['date'] = '211003'
df03['date']=pd.to_datetime(df03['date'], format="%y%m%d")
df03.head(2)
# Out:
#          num   region            title category     time  price  \
# 0  286628166  관악구 봉천동     오뚜기 선물세트 팝니당  생활/가공식품  끌올 2일 전   8000
# 1  269067598  관악구 신원동  보온병 선물세트 2종 새상품  생활/가공식품  끌올 1일 전  15000
#
#                                  detail  interest  chat  view       date
# 0                         유통기한 23.07.01         5     0   225 2021-10-03
# 1  500미리 두개 들어있는 텀블러 선물세트에요\n남서울중학교 직거래        17     3   820 2021-10-03

# %%
df03.to_csv('./seoul_211003_date.csv',encoding='utf-8-sig')

# %% [markdown]
# ## 1004

# %%
path = './전처리/1004/'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.xlsx')]

df04 = pd.DataFrame()
for i in file_list_py:
    data = pd.read_excel(path+i)
    df04 = pd.concat([df04,data])
    
df04 = df04.reset_index(drop = True)
df04
# Out:
#             num     region                      title category       time  \
# 0     293393317  노원구 상계10동    프리미엄 함초 소금 세트 새상품 (선물용)  생활/가공식품  끌올 14시간 전
# 1     291206282   노원구 중계4동     (새상품) 버츠비 핸드크림+립밤 선물세트    뷰티/미용    끌올 4일 전
# 2     236957538    노원구 월계동     더바디샵 브리티쉬로즈 선물세트 판매합니다    뷰티/미용    끌올 4일 전
# 3     292518843    노원구 공릉동                 스팸,참치 선물세트  생활/가공식품    끌올 2일 전
# 4     288488928   노원구 월계2동               동원 선물세트 64R호  생활/가공식품   끌올 9시간 전
# ...         ...        ...                        ...      ...        ...
# 3033  290919123  중랑구 상봉제2동               광천김 선물세트 27봉  생활/가공식품    끌올 4일 전
# 3034  291408714   중랑구 묵제1동             스팸 마일드 8호 선물세트  생활/가공식품       7일 전
# 3035  277975369    중랑구 상봉동              천종산삼배양근 선물세트💪  생활/가공식품    끌올 1일 전
# 3036  291457056  중랑구 상봉제1동                   목우촌 선물세트  생활/가공식품    끌올 5일 전
# 3037  288118844    중랑구 면목동  [새제품]아모레퍼시픽 희망가득 기프트 선물세트    뷰티/미용    끌올 5일 전
#
#       price                                             detail  interest  \
# ...

# %%
df04['date'] = '211004'
df04['date']=pd.to_datetime(df04['date'], format="%y%m%d")
df04.head(2)
# Out:
#          num     region                    title category       time  price  \
# 0  293393317  노원구 상계10동  프리미엄 함초 소금 세트 새상품 (선물용)  생활/가공식품  끌올 14시간 전  20000
# 1  291206282   노원구 중계4동   (새상품) 버츠비 핸드크림+립밤 선물세트    뷰티/미용    끌올 4일 전   5000
#
#                                               detail  interest  chat  view  \
# 0  함초 소금 세트입니다. \n인터넷 최저가 37000원정도 하네요. \n새상품이고 선...         4     0    99
# 1  많이 저렴하게 내놔서 네고는 안됩니다~~ \n\n직거래는 중계벽산3차, 택배는 구매...         2     0    81
#
#         date
# 0 2021-10-04
# 1 2021-10-04

# %%
df04.to_csv('./seoul_211004_date.csv',encoding='utf-8-sig')

# %% [markdown]
# ## 1005

# %%
path = './전처리/1005/'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.xlsx')]

df05 = pd.DataFrame()
for i in file_list_py:
    data = pd.read_excel(path+i)
    df05 = pd.concat([df05,data])
    
df05 = df05.reset_index(drop = True)
df05
# Out:
#             num    region                                             title  \
# 0     284578634   동작구 흑석동                                        키엘 포맨 선물세트
# 1     291941854   동작구 사당동                                  뉴트리라이트 더블엑스 선물세트
# 2     274614094   동작구 사당동                                          록시땅 선물세트
# 3     289733436  동작구 노량진동                                  선물세트 현명한선택 e호 스팸
# 4     287389191   동작구 사당동                                      버블 핸드워시 선물세트
# ...         ...       ...                                               ...
# 3062  227023392   양천구 신정동  “빛나는 생일보내” 스틸라 리퀴드섀도우 선물세트 키튼카르마 미니팁 ( 언더 반짝이 펄)
# 3063  292599855  양천구 신정3동                                 볼빅 골프공 선물셋트(마크포함)
# 3064  287567030  양천구 신월7동                                        명절선물 세트 스팸
# 3065  289625483   양천구 목3동                        하이포크 새우젓으로 맛을 낸 햄 선물세트 팝니다
# 3066  270978904  양천구 신월2동                                      양키캔들 6구 선물세트
#
#      category     time   price  \
# ...

# %%
df05['date'] = '211005'
df05['date']=pd.to_datetime(df05['date'], format="%y%m%d")
df05.head(2)
# Out:
#          num   region             title category     time   price  \
# 0  284578634  동작구 흑석동        키엘 포맨 선물세트  남성패션/잡화  끌올 2일 전   45000
# 1  291941854  동작구 사당동  뉴트리라이트 더블엑스 선물세트  생활/가공식품  끌올 4일 전  120000
#
#                                                                                                                            detail  \
# 0                                                  선물 받았는데 쓰는 제품이 있어서 판매합니다\n훼이셜 퓨얼 에너자이징 토닉250 ml\n모이스쳐라이져 트리트먼트 포 맨 75ml\n증정품2개
# 1  본품1 리필1로 구성된 선물세트로 정가 167000원이네요\n명절선물로 받았는데 먹는 영양제가 많아 내놓아요\n뉴트리라이트 종이백도 같이있어 선물용으로도 좋아요 ^^\n아시는분들은 아시는 고급영양제 더블엑스 저렴하게 데려가세요
#
#    interest  chat  view       date
# 0         4     0    92 2021-10-05
# 1         2     1    76 2021-10-05

# %%
df05.to_csv('./seoul_211005_date.csv',encoding='utf-8-sig')

# %% [markdown]
# ## 1006

# %%
path = './전처리/1006/'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.xlsx')]

df06 = pd.DataFrame()
for i in file_list_py:
    data = pd.read_excel(path+i)
    df06 = pd.concat([df06,data])
    
df06 = df06.reset_index(drop = True)
df06
# Out:
#             num       region                                         title  \
# 0     287040785    용산구 이촌제1동                              청정원 선물셋트 (스페셜1호)
# 1     293579864      용산구 산천동                                       추석 선물세트
# 2     286815133     용산구 동빙고동              💥안상규💥 벌꿀 허니영 선물 세트 새상품💥세계대회 대상 꿀
# 3     284862337      용산구 이촌동  세인트나인 Q soft premium 골프공+골프티 선물세트(2박스 구입 가능)
# 4     287916702      용산구 이촌동               자연을 품은 표고버섯 선물세트 미개봉 새제품 (선물가능)
# ...         ...          ...                                           ...
# 3060  288339925     서대문구 연희동                                   cj 햄선물세트 N호
# 3061  287635172   서대문구 홍제제3동                암웨이 뉴트리라이트 베스트 선물세트(더블엑스, 오메가)
# 3062  285957889   서대문구 홍제제1동                                  설화수 선물세트+쇼핑백
# 3063  292458669    서대문구 남가좌동                              록시땅 핸드크림 립밤 선물세트
# 3064  290430357  서대문구 북가좌제2동                          CJ 현명한 선택 H호 선물세트팝니다
#
#      category      time  price  \
# 0     생활/가공식품   끌올 5일 전  27000
# ...

# %%
df06['date'] = '211006'
df06['date']=pd.to_datetime(df06['date'], format="%y%m%d")
df06.head(2)
# Out:
#          num     region             title category     time  price  \
# 0  287040785  용산구 이촌제1동  청정원 선물셋트 (스페셜1호)  생활/가공식품  끌올 5일 전  27000
# 1  293579864    용산구 산천동           추석 선물세트  생활/가공식품  끌올 1일 전  50000
#
#                                                                                  detail  \
# 0                                         청정원 스페셜 1호 선물셋트 미개봉 새 제품입니다.\n이촌역에서 직거래 원합니다.
# 1  추석선물세트(미개봉) 모두 하시면 일괄 5만원에 다 드리겠습니다 상세설명은 판매페이지 보시면 각각 올려놓았습니다 참고바랍니다 직거래는 성심여고후문입니다
#
#    interest  chat  view       date
# 0         1     2   173 2021-10-06
# 1         4     0   216 2021-10-06

# %%
df06.to_csv('./전처리/seoul/seoul_211006_date.csv',encoding='utf-8-sig')

# %% [markdown]
# ## 1007

# %%
path = './전처리/1007/'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.xlsx')]

df07 = pd.DataFrame()
for i in file_list_py:
    data = pd.read_excel(path+i)
    df07 = pd.concat([df07,data])
    
df07 = df07.reset_index(drop = True)
df07
# Out:
#             num    region                                title category  \
# 0     295481114  양천구 신정4동                           스팸 오일 선물세트  생활/가공식품
# 1     282682808   양천구 목1동                     록시땅 핸드크림 3개 선물셋트    뷰티/미용
# 2     286135340   양천구 신월동           스네일 달팽이 남성 기초화장품 선물세트 추석선물    뷰티/미용
# 3     294160317    양천구 목동                       리챔 선물셋트 15000원  생활/가공식품
# 4     292719408  양천구 신정4동                            고헌정선물셋트1호  생활/가공식품
# ...         ...       ...                                  ...      ...
# 3042  295232676  강남구 대치1동                        샹달프 잼 5종 선물셋트  생활/가공식품
# 3043  295408955   강남구 삼성동                  비오템 핸드크림 + 립밤 선물 세트    뷰티/미용
# 3044  294029609   강남구 역삼동                          소고기 육포 선물세트  생활/가공식품
# 3045  281522617  강남구 압구정동  [연말 선물] YUNJAC 연작 화장품 선물셋트(정품, 미개봉)    뷰티/미용
# 3046  295615938  강남구 삼성1동                      '후'화장품 백화점 선물세트    뷰티/미용
#
#            time   price  \
# 0          1일 전    8000
# 1       끌올 3일 전   30000
# 2       끌올 1일 전   15000
# ...

# %%
df07['date'] = '211007'
df07['date']=pd.to_datetime(df07['date'], format="%y%m%d")
df07.head(2)
# Out:
#          num    region             title category     time  price  \
# 0  295481114  양천구 신정4동        스팸 오일 선물세트  생활/가공식품     1일 전   8000
# 1  282682808   양천구 목1동  록시땅 핸드크림 3개 선물셋트    뷰티/미용  끌올 3일 전  30000
#
#                                                   detail  interest  chat  \
# 0                         이번 추석 선물로 들어온 건데\n너무 많아 내놓습니다.         4     3
# 1  선물 받았으나 제가 쓰는 제품이 아니라 내놓습니다~\n쇼핑백도 있어요~\n30ml 3개 입니다~         5     1
#
#    view       date
# 0    73 2021-10-07
# 1   156 2021-10-07

# %%
df07.to_csv('./전처리/seoul/seoul_211007_date.csv',encoding='utf-8-sig')

# %% [markdown]
# ## 1008

# %%
path = './전처리/1008/'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.xlsx')]

df08 = pd.DataFrame()
for i in file_list_py:
    data = pd.read_excel(path+i)
    df08 = pd.concat([df08,data])
    
df08 = df08.reset_index(drop = True)
df08
# Out:
#             num     region                                     title category  \
# 0     250653769  은평구 갈현제2동                명절선물 엘지생활선물세트 생활의기쁨 37호팝니다    뷰티/미용
# 1     286577302    은평구 불광동                      암웨이 퍼스널케어 선물세트 (새상품)    뷰티/미용
# 2     248555700    은평구 대조동                         새상품)압소바 딸랑이 선물세트       유아동
# 3     286263642    은평구 녹번동                        추석 선물 세트 - 샴푸 세제 등  생활/가공식품
# 4     287121035  은평구 갈현제1동                   프리미엄 참기름 들기름 선물세트 쿠엔즈버킷  생활/가공식품
# ...         ...        ...                                       ...      ...
# 3074  292126414    관악구 봉천동             오늘까지❤미개봉상품❤음양오행 건강선물세트 , 음료세트  생활/가공식품
# 3075  286096233    관악구 성현동  베이비 베이커리 오르골 딸랑이 아기 신발 턱받이 세트 (새상품) 출산선물      유아동
# 3076  290070686    관악구 미성동                            리챔 6호 선물세트 팝니다  생활/가공식품
# 3077  291149769    관악구 신림동                                  스팸1호선물세트  생활/가공식품
# 3078  292400955    관악구 신림동      밀크바오밥 바디워시 1L 바디로션500ml 선물세트 (손잡이박스)    뷰티/미용
#
# ...

# %%
df08['date'] = '211008'
df08['date']=pd.to_datetime(df08['date'], format="%y%m%d")
df08.head(2)
# Out:
#          num     region                       title category     time  price  \
# 0  250653769  은평구 갈현제2동  명절선물 엘지생활선물세트 생활의기쁨 37호팝니다    뷰티/미용  끌올 8일 전  20000
# 1  286577302    은평구 불광동        암웨이 퍼스널케어 선물세트 (새상품)    뷰티/미용  끌올 2일 전  40000
#
#                                               detail  interest  chat  view  \
# 0  엘지생활선물세트 생활의기쁨 37호\n팝니다 새상품 이구요\n유통기한23년 까지입니다...         8     1   258
# 1  암웨이 퍼스널케어 선물세트 미개봉 새상품입니다. 유통기한 넉넉하고 외관 깨끗하여 선...         5     3   233
#
#         date
# 0 2021-10-08
# 1 2021-10-08

# %%
df08.to_csv('./전처리/seoul/seoul_211008_date.csv',encoding='utf-8-sig')

# %% [markdown]
# ## 전체 전처리

# %%
path = './전처리/seoul/'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.csv')]

df = pd.DataFrame()
for i in file_list_py:
    data = pd.read_csv(path+i)
    df = pd.concat([df,data])
    
df = df.reset_index(drop = True)
df = df.drop(['Unnamed: 0'],axis=1)
df
# Out:
#              num       region                           title category  \
# 0      250653769    은평구 갈현제2동      명절선물 엘지생활선물세트 생활의기쁨 37호팝니다    뷰티/미용
# 1      286577302      은평구 불광동            암웨이 퍼스널케어 선물세트 (새상품)    뷰티/미용
# 2      248555700      은평구 대조동               새상품)압소바 딸랑이 선물세트       유아동
# 3      286263642      은평구 녹번동              추석 선물 세트 - 샴푸 세제 등  생활/가공식품
# 4      287121035    은평구 갈현제1동         프리미엄 참기름 들기름 선물세트 쿠엔즈버킷  생활/가공식품
# ...          ...          ...                             ...      ...
# 38916  288339925     서대문구 연희동                     cj 햄선물세트 N호  생활/가공식품
# 38917  287635172   서대문구 홍제제3동  암웨이 뉴트리라이트 베스트 선물세트(더블엑스, 오메가)  생활/가공식품
# 38918  285957889   서대문구 홍제제1동                    설화수 선물세트+쇼핑백    뷰티/미용
# 38919  292458669    서대문구 남가좌동                록시땅 핸드크림 립밤 선물세트    뷰티/미용
# 38920  290430357  서대문구 북가좌제2동            CJ 현명한 선택 H호 선물세트팝니다  생활/가공식품
#
#            time  price                                             detail  \
# ...

# %%
df['gu'] = df['region'].str.split(' ',expand=True)[0]
df['dong'] = df['region'].str.split(' ', expand=True)[1]
df.head(2)
# Out:
#          num     region                       title category     time  price  \
# 0  250653769  은평구 갈현제2동  명절선물 엘지생활선물세트 생활의기쁨 37호팝니다    뷰티/미용  끌올 8일 전  20000
# 1  286577302    은평구 불광동        암웨이 퍼스널케어 선물세트 (새상품)    뷰티/미용  끌올 2일 전  40000
#
#                                               detail  interest  chat  view  \
# 0  엘지생활선물세트 생활의기쁨 37호\n팝니다 새상품 이구요\n유통기한23년 까지입니다...         8     1   258
# 1  암웨이 퍼스널케어 선물세트 미개봉 새상품입니다. 유통기한 넉넉하고 외관 깨끗하여 선...         5     3   233
#
#          date   gu   dong
# 0  2021-10-08  은평구  갈현제2동
# 1  2021-10-08  은평구    불광동

# %%
df.gu[[25685]]
# Out:
# 25685    성북구
# Name: gu, dtype: object

# %%
df.to_csv('./전처리/seoul_date_211008_중복제거X.csv',encoding='utf-8-sig')

# %%
df.to_excel('./전처리/seoul_date_211008_중복제거X.xlsx',encoding='utf-8-sig')

# %%
32795 + 3047
# Out:
# 35842

# %%
df['gu'].unique()
# Out:
# array(['관악구', '중랑구', '서대문구', '강서구', '송파구', '구로구', '광진구', '서초구', '도봉구',
#        '성동구', '강남구', '은평구', '중구', '노원구', '강동구', '영등포구', '금천구', '양천구',
#        '동작구', '용산구', '마포구', '종로구', '동대문구', '강북구', '성북구'], dtype=object)

# %%
df['dong'].unique()
# Out:
# array(['봉천동', '신원동', '서원동', '신림동', '은천동', '신사동', '난곡동', '청룡동', '행운동',
#        '남현동', '인헌동', '청림동', '대학동', '중앙동', '보라매동', '성현동', '낙성대동', '조원동',
#        '미성동', '난향동', '서림동', '중화동', '면목본동', '묵동', '상봉동', '중화제1동', '상봉제2동',
#        '신내2동', '망우동', '면목제2동', '면목동', '신내동', '상봉제1동', '신내1동', '면목제7동',
#        '묵제1동', '망우제3동', '망우본동', '묵제2동', '중화제2동', '면목제3.8동', '연희동', '창천동',
#        '북아현동', '현저동', '홍제제3동', '홍은동', '북가좌동', '충정로3가', '옥천동', '홍은제1동',
#        '홍제제1동', '홍제동', '대현동', '북가좌제2동', '북가좌제1동', '신촌동', '홍은제2동', '충현동',
#        '남가좌동', '충정로2가', '천연동', '남가좌제1동', '대신동', '남가좌제2동', '방화제1동',
#        '화곡제1동', '화곡동', '마곡동', '염창동', '내발산동', '등촌동', '등촌제3동', '방화동',
#        '화곡본동', '화곡제3동', '방화제2동', '발산제1동', '가양동', '화곡제6동', '가양제3동',
#        '화곡제4동', '등촌제1동', '등촌제2동', '우장산동', '화곡제2동', '공항동', '석촌동', '잠실7동',
#        '문정2동', '거여2동', '잠실2동', '위례동', '잠실3동', '가락동', '문정동', '방이2동', '삼전동',
#        '잠실본동', '가락2동', '송파동', '가락1동', '오금동', '송파2동', '문정1동', '풍납2동',
# ...

# %%
df[df['gu']=='안암동'].index
# Out:
# Int64Index([], dtype='int64')

# %%
df['dong'][[15420, 15432, 15474, 20117, 24281, 24285, 24426, 28731, 28734,28764]] = '안암동'
# Out:
# <ipython-input-9-30c283bead22>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dong'][[15420, 15432, 15474, 20117, 24281, 24285, 24426, 28731, 28734,28764]] = '안암동'

# %%
df['gu'][[15420, 15432, 15474, 20117, 24281, 24285, 24426, 28731, 28734,28764]] = '성북구'
# Out:
# <ipython-input-10-9d5753407941>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gu'][[15420, 15432, 15474, 20117, 24281, 24285, 24426, 28731, 28734,28764]] = '성북구'
